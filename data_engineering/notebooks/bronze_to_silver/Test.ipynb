# %%
spark.sql("""
CREATE schema table.test.schema1
""")
# Out:
# DataFrame[]

# %%
# %%sparksql
# drop namespace tables.platinum
# Out:
# <table><tr style="border-bottom: 1px solid"></tr></table>

# %%
spark.sql("""
CREATE TABLE tables.bronze.my_first_table (
    id INT,
    name STRING
)
USING iceberg
""")
# Out:
# DataFrame[]
